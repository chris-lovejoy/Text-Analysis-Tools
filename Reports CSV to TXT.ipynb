# %% [markdown]
# # CSV file to TXT file conversion
#
# Combine cells in a CSV file to produce a single text file output.

# %%
#Import CSV file

import pandas as pd
data = pd.read_csv('../Reports.csv').dropna()
data
# Out:
#                                         message_manager  Length
# 0     Hi Martin,\nGood morning. This was the detaile...    6968
# 1     Not urgent \n\nMessage for Roy from Lorraine. ...    6345
# 2     Increase of pay \n\nHello,\n\nIt’s been 15 m...    4917
# 3     Concerning Harold's well-being and the fall he...    3609
# 4     Upon arrival Winnie answered the door and intr...    3536
# 5     Upon arrival greeted Winnie and Andrew in bed ...    2861
# 6     Today while in the bathroom downstairs after a...    2644
# 7     The live-in staff let me in,met Gayle standing...    2625
# 8     Upon arrival at 21.09 called to Rashida inform...    2591
# 9     Upon arrival Winnie answered the door greeted ...    2589
# 10    Upon arrival greeted Winnie and go to the bedr...    2585
# 11    Yesterday  30 october done a cover up for the ...    2323
# 12    Yesterday  30 october done a cover up for the ...    2323
# 13    Yesterday  30 october done a cover up for the ...    2323
# 14    Dr Alan had an incident at 4 o’clock early i...    2244
# 15    Upon arrival Rashida’s daughter: Jean answer...    2202
# 16    When Leyla came to David’s house, David star...    2111
# 17    Mrs Bridger calling for help at 4.45am she cou...    2084
# 18    My first week with Gayel Dee before to left as...    2005
# 19    Upon arrival, greeted Ernie and asked how he s...    1974
# 20    11-12.30\nUpon arrival greeted Winnie when  sh...    1956
# 21    I arrived at 9.30am and was greeted by one of ...    1817
# 22    On this day on my visit the live in care went ...    1718
# 23    I had contact at 17.34pm from out of hours. I ...    1701
# 24    Upon arrival Mrs Reid was sleeping, allowed fe...    1620
# 25    Upon arrival Mrs Reid was sleeping, allowed fe...    1589
# 26    Hi Martin/Manuella\n\n●Cathy and George said...    1567
# 27    Upon arrival greeted Mrs Reid’s son and aske...    1476
# 28    I'm concerned about fire safety and risk of bu...    1448
# 29    Renee had drank of fluid 600mls. but not able ...    1413
# ...                                                 ...     ...
# 7361                                                 No       2
# 7362                                                 No       2
# 7363                                                 No       2
# 7364                                                 No       2
# 7365                                                 No       2
# 7366                                                 No       2
# 7367                                                 No       2
# 7368                                                 No       2
# 7369                                                 No       2
# 7370                                                 No       2
# 7371                                                 No       2
# 7372                                                 No       2
# 7373                                                 No       2
# 7374                                                 No       2
# 7375                                                  .       1
# 7376                                                  .       1
# 7377                                                  .       1
# 7378                                                  .       1
# 7379                                                  .       1
# 7380                                                  .       1
# 7381                                                  .       1
# 7382                                                  .       1
# 7383                                                  .       1
# 7384                                                  .       1
# 7385                                                  .       1
# 7386                                                  .       1
# 7387                                                  .       1
# 7388                                                  I       1
# 7389                                                  N       1
# 7390                                                  O       1
#
# [7366 rows x 2 columns]

# %%
# concatenate cells into one string 'output'

length = len(data)
output = ""

for i in range (1, 6000):
    output += data['message_manager'][i] + " "

# %%
# visualise output
print(output[100:1100])
print("")
print('Type is ', type(output))
print('Length is ', len(output))
# Out:
# ge all Fridays to Thursdays
#
# Following  our chat the other day about the cleaning tasks at Tony Kelly's - from speaking to Mary, she gave me the impression that the cleaning  is her agreement with Cera. When  I arrived i did not say anything about what you asked  me the day Maryan visited to cover my absence. Soon after I arrived Mary said the girl Cera sent said she only gets The patients out of bed, does washes, and breakfast.
#
#  Mary said  she then told her the cleaning is part of Mary's agreement with cera.  So i asked Mary if Maryam refused to clean, because if she's unhappy witu anything she has the right to ring the office, she said no no no dont talk to anyone about this, Maryan was good actually and she said was pleased that maryan agreed to do the cleaning and that's what she got her to do pretty much most of the time
#
# ●●●Areas that I keep clean that are not on the checklist on my visit
# ■tenants bathroom upstairs,  I do bathtub,  taps, wall tiles, bath panel, over bat
#
# Type is  <class 'str'>
# Length is  1280943

# %%
# Write file to text output
text_file = open("output.txt", "w")

text_file.write(output)

text_file.close()
